# %% [markdown]
# ## Dealing with missing values

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
data=sns.load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#load the dataset
data=sns.load_dataset('titanic')
data.head()
plt.figure(figsize=(10,6))
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %% [markdown]
# ## How to know missing values in data

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
# pclass           0
# survived         0
# fare             0
# parch            0
# sibsp            0
# class            0
# adult_male       0
# who              0
# alive            0
# alone            0
# dtype: int64

# %%
round(data.isnull().sum() / len(data) * 100, 2).sort_values(ascending=False)
# Out:
# deck           77.22
# age            19.87
# embarked        0.22
# embark_town     0.22
# sex             0.00
# pclass          0.00
# survived        0.00
# fare            0.00
# parch           0.00
# sibsp           0.00
# class           0.00
# adult_male      0.00
# who             0.00
# alive           0.00
# alone           0.00
# dtype: float64

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
# load titanic dataset
data = sns.load_dataset('titanic')

# calculate missing values
print("----------------------------------------")
print(f"Missing values in each column:\n{data.isnull().sum().sort_values(ascending=False)}")
print("----------------------------------------")
print(f"Percentage of missing values in each column:\n{round(data.isnull().sum() / len(data) * 100, 2).sort_values(ascending=False)}")
# Out:
# ----------------------------------------
# Missing values in each column:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
# pclass           0
# survived         0
# fare             0
# parch            0
# sibsp            0
# class            0
# adult_male       0
# who              0
# alive            0
# alone            0
# dtype: int64
# ----------------------------------------
# Percentage of missing values in each column:
# deck           77.22
# age            19.87
# embarked        0.22
# embark_town     0.22
# sex             0.00
# pclass          0.00
# survived        0.00
# fare            0.00
# parch           0.00
# sibsp           0.00
# class           0.00
# adult_male      0.00
# who             0.00
# alive           0.00
# alone           0.00
# dtype: float64

# %% [markdown]
# ## Handle Missing Values
#
# ## 1. Through median method

# %%
data['age']=data['age'].fillna(data['age'].median())
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## 2. Through forward fill method

# %%
data['age']= data['age'].ffill
data
# Out:
#      survived  pclass     sex  \
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    age  sibsp  parch     fare  \
# 0    <bound method NDFrame.ffill of 0      22.0\n1 ...      1      0   7.2500
# 1    <bound method NDFrame.ffill of 0      22.0\n1 ...      1      0  71.2833
# 2    <bound method NDFrame.ffill of 0      22.0\n1 ...      0      0   7.9250
# 3    <bound method NDFrame.ffill of 0      22.0\n1 ...      1      0  53.1000
# 4    <bound method NDFrame.ffill of 0      22.0\n1 ...      0      0   8.0500
# ..                                                 ...    ...    ...      ...
# ...

# %% [markdown]
# ## Through Backward Fill

# %%
data['age']= data['age'].bfill
data
# Out:
#      survived  pclass     sex  \
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    age  sibsp  parch     fare  \
# 0    <bound method NDFrame.bfill of 0      <bound m...      1      0   7.2500
# 1    <bound method NDFrame.bfill of 0      <bound m...      1      0  71.2833
# 2    <bound method NDFrame.bfill of 0      <bound m...      0      0   7.9250
# 3    <bound method NDFrame.bfill of 0      <bound m...      1      0  53.1000
# 4    <bound method NDFrame.bfill of 0      <bound m...      0      0   8.0500
# ..                                                 ...    ...    ...      ...
# ...

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# Ensure 'age' exists and convert to numeric, coercing errors to NaN
data['age'] = pd.to_numeric(data['age'], errors='coerce')

# Check if there are any numeric values left
if data['age'].notna().sum() == 0:
    print("Error: 'age' column has no numeric values to impute.")
else:
    # Create KNNImputer
    imputer = KNNImputer(n_neighbors=5)

    # Impute missing values
    data['age'] = imputer.fit_transform(data[['age']])
# Out:
# Error: 'age' column has no numeric values to impute.

# %%
# drop rows having missing values
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     0 non-null      int64
#  1   pclass       0 non-null      int64
#  2   sex          0 non-null      object
#  3   age          0 non-null      float64
#  4   sibsp        0 non-null      int64
#  5   parch        0 non-null      int64
#  6   fare         0 non-null      float64
#  7   embarked     0 non-null      object
#  8   class        0 non-null      category
#  9   who          0 non-null      object
#  10  adult_male   0 non-null      bool
#  11  deck         0 non-null      category
#  12  embark_town  0 non-null      object
#  13  alive        0 non-null      object
#  14  alone        0 non-null      bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 488.0+ bytes
